# %%
from datetime import datetime

now = datetime.now()
now
# Out:
# datetime.datetime(2025, 5, 26, 10, 22, 21, 608254)

# %%
t1 = datetime.now()
t2 = datetime(1970, 1, 1)
t1
# Out:
# datetime.datetime(2025, 5, 26, 10, 22, 45, 581680)

# %%
t2
# Out:
# datetime.datetime(1970, 1, 1, 0, 0)

# %%
diff = t1 - t2
print(diff)
# Out:
# 20234 days, 10:22:45.581680

# %%
type(diff)
# Out:
# datetime.timedelta

# %%
import pandas as pd

ebola = pd.read_csv('../data/country_timeseries.csv')
print(ebola.iloc[:5, :5])
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
ebola['date_dt'] = pd.to_datetime(ebola['Date'])

# %%
ebola['date_dt'] = pd.to_datetime(ebola['Date'], format = '%m/%d/%Y')

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
#  18  date_dt              122 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(16), int64(1), object(1)
# memory usage: 18.2+ KB

# %%
print(ebola.iloc[:5, 15:])
# Out:
#    Deaths_UnitedStates  Deaths_Spain  Deaths_Mali    date_dt
# 0                  NaN           NaN          NaN 2015-01-05
# 1                  NaN           NaN          NaN 2015-01-04
# 2                  NaN           NaN          NaN 2015-01-03
# 3                  NaN           NaN          NaN 2015-01-02
# 4                  NaN           NaN          NaN 2014-12-31

# %%
ebola = pd.read_csv('../data/country_timeseries.csv', parse_dates = ['Date'])
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# memory usage: 17.3 KB

# %%
d = pd.date_range('2025-05-26', periods = 10, freq = 'D')
print(d[0] + 1 * d.freq)
# Out:
# 2025-05-27 00:00:00

# %%
print(d.year)
# Out:
# Index([2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025], dtype='int32')

# %%
ebola['date_dt'] =pd.to_datetime(ebola['Date'])
ebola[['Date', 'date_dt']]
# Out:
#           Date    date_dt
# 0   2015-01-05 2015-01-05
# 1   2015-01-04 2015-01-04
# 2   2015-01-03 2015-01-03
# 3   2015-01-02 2015-01-02
# 4   2014-12-31 2014-12-31
# ..         ...        ...
# 117 2014-03-27 2014-03-27
# 118 2014-03-26 2014-03-26
# 119 2014-03-25 2014-03-25
# 120 2014-03-24 2014-03-24
# 121 2014-03-22 2014-03-22
#
# [122 rows x 2 columns]

# %%
ebola['year'] = ebola['date_dt'].dt.year
ebola[['Date', 'date_dt', 'year']]
# Out:
#           Date    date_dt  year
# 0   2015-01-05 2015-01-05  2015
# 1   2015-01-04 2015-01-04  2015
# 2   2015-01-03 2015-01-03  2015
# 3   2015-01-02 2015-01-02  2015
# 4   2014-12-31 2014-12-31  2014
# ..         ...        ...   ...
# 117 2014-03-27 2014-03-27  2014
# 118 2014-03-26 2014-03-26  2014
# 119 2014-03-25 2014-03-25  2014
# 120 2014-03-24 2014-03-24  2014
# 121 2014-03-22 2014-03-22  2014
#
# [122 rows x 3 columns]

# %%
ebola = ebola.assign(
    month = ebola['date_dt'].dt.month,
    day = ebola['date_dt'].dt.day
)
print(ebola[['Date', 'year', 'month', 'day']])
# Out:
#           Date  year  month  day
# 0   2015-01-05  2015      1    5
# 1   2015-01-04  2015      1    4
# 2   2015-01-03  2015      1    3
# 3   2015-01-02  2015      1    2
# 4   2014-12-31  2014     12   31
# ..         ...   ...    ...  ...
# 117 2014-03-27  2014      3   27
# 118 2014-03-26  2014      3   26
# 119 2014-03-25  2014      3   25
# 120 2014-03-24  2014      3   24
# 121 2014-03-22  2014      3   22
#
# [122 rows x 4 columns]

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
#  18  date_dt              122 non-null    datetime64[ns]
#  19  year                 122 non-null    int32
#  20  month                122 non-null    int32
#  21  day                  122 non-null    int32
# dtypes: datetime64[ns](2), float64(16), int32(3), int64(1)
# memory usage: 19.7 KB

# %%
ebola['date_dt'].min()
# Out:
# Timestamp('2014-03-22 00:00:00')

# %%
ebola['outbreak_d'] = ebola['date_dt'] - ebola['date_dt'].min()
ebola[['Date', 'outbreak_d']]
# Out:
#           Date outbreak_d
# 0   2015-01-05   289 days
# 1   2015-01-04   288 days
# 2   2015-01-03   287 days
# 3   2015-01-02   286 days
# 4   2014-12-31   284 days
# ..         ...        ...
# 117 2014-03-27     5 days
# 118 2014-03-26     4 days
# 119 2014-03-25     3 days
# 120 2014-03-24     2 days
# 121 2014-03-22     0 days
#
# [122 rows x 2 columns]

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
#  18  date_dt              122 non-null    datetime64[ns]
#  19  year                 122 non-null    int32
#  20  month                122 non-null    int32
#  21  day                  122 non-null    int32
#  22  outbreak_d           122 non-null    timedelta64[ns]
# dtypes: datetime64[ns](2), float64(16), int32(3), int64(1), timedelta64[ns](1)
# memory usage: 20.6 KB

# %%
banks = pd.read_csv('../data/banklist.csv')
banks.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 2  58302                         Whitney Bank    28-Apr-17    26-Jul-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %%
banks = pd.read_csv(
    '../data/banklist.csv', parse_dates = ['Closing Date', 'Updated Date']
)
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              553 non-null    object
#  1   City                   553 non-null    object
#  2   ST                     553 non-null    object
#  3   CERT                   553 non-null    int64
#  4   Acquiring Institution  553 non-null    object
#  5   Closing Date           553 non-null    datetime64[ns]
#  6   Updated Date           553 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.4+ KB
# C:\Users\user\AppData\Local\Temp\ipykernel_22736\441428365.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks = pd.read_csv(
# C:\Users\user\AppData\Local\Temp\ipykernel_22736\441428365.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   banks = pd.read_csv(

# %%
banks = banks.assign(
    closing_quarter = banks['Closing Date'].dt.quarter,
    closing_year = banks['Closing Date'].dt.year
)
banks
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
#      ST   CERT                Acquiring Institution Closing Date Updated Date  \
# 0    IL   1802            United Fidelity Bank, fsb   2017-05-26   2017-07-26
# 1    WI  30003  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26
# 2    LA  58302                         Whitney Bank   2017-04-28   2017-07-26
# 3    UT  35495                    Cache Valley Bank   2017-03-03   2017-05-18
# 4    IL  19328                  State Bank of Texas   2017-01-27   2017-05-18
# ..   ..    ...                                  ...          ...          ...
# 548  IL  32646                Superior Federal, FSB   2001-07-27   2014-08-19
# 549  OH   6629                    North Valley Bank   2001-05-03   2002-11-18
# 550  NH  34264  Southern New Hampshire Bank & Trust   2001-02-02   2003-02-18
# 551  IL   3815              Banterra Bank of Marion   2000-12-14   2005-03-17
# 552  HI  21029                   Bank of the Orient   2000-10-13   2005-03-17
#
#      closing_quarter  closing_year
# 0                  2          2017
# 1                  2          2017
# 2                  2          2017
# 3                  1          2017
# 4                  1          2017
# ..               ...           ...
# 548                3          2001
# 549                2          2001
# 550                1          2001
# 551                4          2000
# 552                4          2000
#
# [553 rows x 9 columns]

# %%
closing_year = banks.groupby(['closing_year']).size()
closing_year
# Out:
# closing_year
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      6
# dtype: int64

# %%
closing_year_q = (
    banks
    .groupby(['closing_year', 'closing_quarter'])
    .size()
)
closing_year_q
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
#               2                  45
#               3                  41
#               4                  30
# 2011          1                  26
#               2                  22
#               3                  26
#               4                  18
# 2012          1                  16
#               2                  15
#               3                  12
#               4                   8
# 2013          1                   4
#               2                  12
#               3                   6
#               4                   2
# 2014          1                   5
#               2                   7
#               3                   2
#               4                   4
# 2015          1                   4
#               2                   1
#               3                   1
#               4                   2
# 2016          1                   1
#               2                   2
#               3                   2
# 2017          1                   3
#               2                   3
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax = closing_year.plot()
plt.show()

# %%
fig, ax = plt.subplots()
ax = closing_year_q.plot()
plt.show()

# %%
pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting lxml (from pandas-datareader)
#   Downloading lxml-5.4.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\user\anaconda3\envs\python\lib\site-packages (from pandas-datareader) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\user\anaconda3\envs\python\lib\site-packages (from pandas-datareader) (2.32.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\user\anaconda3\envs\python\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\envs\python\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\python\lib\site-packages (from pandas>=0.23->pandas-datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\python\lib\site-packages (from pandas>=0.23->pandas-datareader) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\python\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\python\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\python\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\python\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\python\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2025.4.26)
# Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Downloading lxml-5.4.0-cp310-cp310-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------- ----------------------- 1.6/3.8 MB 8.4 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 8.1 MB/s eta 0:00:00
# Installing collected packages: lxml, pandas-datareader
#
#    ---------------------------------------- 0/2 [lxml]
#    -------------------- ------------------- 1/2 [pandas-datareader]
#    ---------------------------------------- 2/2 [pandas-datareader]
#
# Successfully installed lxml-5.4.0 pandas-datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader.data as web

tesla = web.DataReader('TSLA', 'stooq')
tesla
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2025-05-23  337.9200  343.1800  333.2100  339.3400   84654818
# 2025-05-22  331.9000  347.2700  331.3900  341.0400   97113416
# 2025-05-21  344.4300  347.3500  332.2000  334.6200  102354844
# 2025-05-20  347.8700  354.9899  341.6300  343.8200  131715548
# 2025-05-19  336.3000  343.0000  333.3700  342.0900   88869853
# ...              ...       ...       ...       ...        ...
# 2020-06-02   59.6467   60.5767   58.0667   58.7700  203483940
# 2020-06-01   57.2000   59.9333   56.9400   59.8733  226279455
# 2020-05-29   53.9167   55.6667   53.6133   55.6667  177187335
# 2020-05-28   54.2333   54.9833   53.4467   53.7200  109136610
# 2020-05-27   54.7233   55.1800   52.3333   54.6833  173242950
#
# [1256 rows x 5 columns]

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2025-05-23 to 2020-05-27
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
tesla.index
# Out:
# DatetimeIndex(['2025-05-23', '2025-05-22', '2025-05-21', '2025-05-20',
#                '2025-05-19', '2025-05-16', '2025-05-15', '2025-05-14',
#                '2025-05-13', '2025-05-12',
#                ...
#                '2020-06-09', '2020-06-08', '2020-06-05', '2020-06-04',
#                '2020-06-03', '2020-06-02', '2020-06-01', '2020-05-29',
#                '2020-05-28', '2020-05-27'],
#               dtype='datetime64[ns]', name='Date', length=1256, freq=None)

# %%
tesla = pd.read_csv('../data/tesla_stock_yahoo.csv')
tesla.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tesla = pd.read_csv(
    '../data/tesla_stock_yahoo.csv', parse_dates = ['Date']
)
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1791 entries, 0 to 1790
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1791 non-null   datetime64[ns]
#  1   Open       1791 non-null   float64
#  2   High       1791 non-null   float64
#  3   Low        1791 non-null   float64
#  4   Close      1791 non-null   float64
#  5   Adj Close  1791 non-null   float64
#  6   Volume     1791 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 98.1 KB

# %%
print(
    tesla.loc[
        (tesla.Date.dt.year == 2010) & (tesla.Date.dt.month == 6)
    ]
)
# Out:
#                Date       Open   High        Low      Close  Adj Close  \
# ref_date
# 0 days   2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999
# 1 days   2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000
#
#             Volume ref_date
# ref_date
# 0 days    18766300   0 days
# 1 days    17187100   1 days

# %%
tesla.index = tesla['Date']
tesla
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2010-06-29 2010-06-29   19.000000   25.000000   17.540001   23.889999
# 2010-06-30 2010-06-30   25.790001   30.420000   23.299999   23.830000
# 2010-07-01 2010-07-01   25.000000   25.920000   20.270000   21.959999
# 2010-07-02 2010-07-02   23.000000   23.100000   18.709999   19.200001
# 2010-07-06 2010-07-06   20.000000   20.000000   15.830000   16.110001
# ...               ...         ...         ...         ...         ...
# 2017-08-02 2017-08-02  318.940002  327.119995  311.220001  325.890015
# 2017-08-03 2017-08-03  345.329987  350.000000  343.149994  347.089996
# 2017-08-04 2017-08-04  347.000000  357.269989  343.299988  356.910004
# 2017-08-07 2017-08-07  357.350006  359.480011  352.750000  355.170013
# 2017-08-08 2017-08-08  357.529999  368.579987  357.399994  365.220001
#
#              Adj Close    Volume  ref_date
# Date
# 2010-06-29   23.889999  18766300    0 days
# 2010-06-30   23.830000  17187100    1 days
# 2010-07-01   21.959999   8218800    2 days
# 2010-07-02   19.200001   5139800    3 days
# 2010-07-06   16.110001   6866900    7 days
# ...                ...       ...       ...
# 2017-08-02  325.890015  13091500 2591 days
# 2017-08-03  347.089996  13535000 2592 days
# 2017-08-04  356.910004   9198400 2593 days
# 2017-08-07  355.170013   6276900 2596 days
# 2017-08-08  365.220001   7449837 2597 days
#
# [1791 rows x 8 columns]

# %%
tesla.loc['2015']
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2015-01-02 2015-01-02  222.869995  223.250000  213.259995  219.309998
# 2015-01-05 2015-01-05  214.550003  216.500000  207.160004  210.089996
# 2015-01-06 2015-01-06  210.059998  214.199997  204.210007  211.279999
# 2015-01-07 2015-01-07  213.350006  214.779999  209.779999  210.949997
# 2015-01-08 2015-01-08  212.809998  213.800003  210.009995  210.619995
# ...               ...         ...         ...         ...         ...
# 2015-12-24 2015-12-24  230.559998  231.880005  228.279999  230.570007
# 2015-12-28 2015-12-28  231.490005  231.979996  225.539993  228.949997
# 2015-12-29 2015-12-29  230.059998  237.720001  229.550003  237.190002
# 2015-12-30 2015-12-30  236.600006  243.630005  235.669998  238.089996
# 2015-12-31 2015-12-31  238.509995  243.449997  238.369995  240.009995
#
#              Adj Close   Volume  ref_date
# Date
# 2015-01-02  219.309998  4764400 1648 days
# 2015-01-05  210.089996  5368500 1651 days
# 2015-01-06  211.279999  6261900 1652 days
# 2015-01-07  210.949997  2968400 1653 days
# 2015-01-08  210.619995  3442500 1654 days
# ...                ...      ...       ...
# 2015-12-24  230.570007   708000 2004 days
# 2015-12-28  228.949997  1901300 2008 days
# 2015-12-29  237.190002  2406300 2009 days
# 2015-12-30  238.089996  3697900 2010 days
# 2015-12-31  240.009995  2683200 2011 days
#
# [252 rows x 8 columns]

# %%
tesla['ref_date'] = tesla['Date'] - tesla['Date'].min()
tesla
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2010-06-29 2010-06-29   19.000000   25.000000   17.540001   23.889999
# 2010-06-30 2010-06-30   25.790001   30.420000   23.299999   23.830000
# 2010-07-01 2010-07-01   25.000000   25.920000   20.270000   21.959999
# 2010-07-02 2010-07-02   23.000000   23.100000   18.709999   19.200001
# 2010-07-06 2010-07-06   20.000000   20.000000   15.830000   16.110001
# ...               ...         ...         ...         ...         ...
# 2017-08-02 2017-08-02  318.940002  327.119995  311.220001  325.890015
# 2017-08-03 2017-08-03  345.329987  350.000000  343.149994  347.089996
# 2017-08-04 2017-08-04  347.000000  357.269989  343.299988  356.910004
# 2017-08-07 2017-08-07  357.350006  359.480011  352.750000  355.170013
# 2017-08-08 2017-08-08  357.529999  368.579987  357.399994  365.220001
#
#              Adj Close    Volume  ref_date
# Date
# 2010-06-29   23.889999  18766300    0 days
# 2010-06-30   23.830000  17187100    1 days
# 2010-07-01   21.959999   8218800    2 days
# 2010-07-02   19.200001   5139800    3 days
# 2010-07-06   16.110001   6866900    7 days
# ...                ...       ...       ...
# 2017-08-02  325.890015  13091500 2591 days
# 2017-08-03  347.089996  13535000 2592 days
# 2017-08-04  356.910004   9198400 2593 days
# 2017-08-07  355.170013   6276900 2596 days
# 2017-08-08  365.220001   7449837 2597 days
#
# [1791 rows x 8 columns]

# %%
tesla.index = tesla['ref_date']
tesla
# Out:
#                 Date        Open        High         Low       Close  \
# ref_date
# 0 days    2010-06-29   19.000000   25.000000   17.540001   23.889999
# 1 days    2010-06-30   25.790001   30.420000   23.299999   23.830000
# 2 days    2010-07-01   25.000000   25.920000   20.270000   21.959999
# 3 days    2010-07-02   23.000000   23.100000   18.709999   19.200001
# 7 days    2010-07-06   20.000000   20.000000   15.830000   16.110001
# ...              ...         ...         ...         ...         ...
# 2591 days 2017-08-02  318.940002  327.119995  311.220001  325.890015
# 2592 days 2017-08-03  345.329987  350.000000  343.149994  347.089996
# 2593 days 2017-08-04  347.000000  357.269989  343.299988  356.910004
# 2596 days 2017-08-07  357.350006  359.480011  352.750000  355.170013
# 2597 days 2017-08-08  357.529999  368.579987  357.399994  365.220001
#
#             Adj Close    Volume  ref_date
# ref_date
# 0 days      23.889999  18766300    0 days
# 1 days      23.830000  17187100    1 days
# 2 days      21.959999   8218800    2 days
# 3 days      19.200001   5139800    3 days
# 7 days      16.110001   6866900    7 days
# ...               ...       ...       ...
# 2591 days  325.890015  13091500 2591 days
# 2592 days  347.089996  13535000 2592 days
# 2593 days  356.910004   9198400 2593 days
# 2596 days  355.170013   6276900 2596 days
# 2597 days  365.220001   7449837 2597 days
#
# [1791 rows x 8 columns]

# %%
tesla.loc['0 day' : '10 day']
# Out:
#                Date       Open       High        Low      Close  Adj Close  \
# ref_date
# 0 days   2010-06-29  19.000000  25.000000  17.540001  23.889999  23.889999
# 1 days   2010-06-30  25.790001  30.420000  23.299999  23.830000  23.830000
# 2 days   2010-07-01  25.000000  25.920000  20.270000  21.959999  21.959999
# 3 days   2010-07-02  23.000000  23.100000  18.709999  19.200001  19.200001
# 7 days   2010-07-06  20.000000  20.000000  15.830000  16.110001  16.110001
# 8 days   2010-07-07  16.400000  16.629999  14.980000  15.800000  15.800000
# 9 days   2010-07-08  16.139999  17.520000  15.570000  17.459999  17.459999
# 10 days  2010-07-09  17.580000  17.900000  16.549999  17.400000  17.400000
#
#             Volume ref_date
# ref_date
# 0 days    18766300   0 days
# 1 days    17187100   1 days
# 2 days     8218800   2 days
# 3 days     5139800   3 days
# 7 days     6866900   7 days
# 8 days     6921700   8 days
# 9 days     7711400   9 days
# 10 days    4050600  10 days

# %%
ebola = pd.read_csv(
    '../data/country_timeseries.csv', parse_dates = ['Date']
)
print(ebola.iloc[:, :5])
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0   2015-01-05  289        2776.0            NaN            10030.0
# 1   2015-01-04  288        2775.0            NaN             9780.0
# 2   2015-01-03  287        2769.0         8166.0             9722.0
# 3   2015-01-02  286           NaN         8157.0                NaN
# 4   2014-12-31  284        2730.0         8115.0             9633.0
# ..         ...  ...           ...            ...                ...
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN
#
# [122 rows x 5 columns]

# %%
head_range = pd.date_range(start = '2014-12-31', end = '2015-01-05')
head_range
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
ebola_5 = ebola.head()

# %%
ebola_5.index = ebola_5['Date']

# %%
ebola_5 = ebola_5.reindex(head_range)
ebola_5.iloc[:, :5]
# Out:
#                  Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 2014-12-31 2014-12-31  284.0        2730.0         8115.0             9633.0
# 2015-01-01        NaT    NaN           NaN            NaN                NaN
# 2015-01-02 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-03 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-04 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-05 2015-01-05  289.0        2776.0            NaN            10030.0

# %%
ebola.index = ebola['Date']

fig, ax = plt.subplots()
ax = ebola.plot(ax = ax)
ax.legend(fontsize = 7, loc = 2, borderaxespad = 1.0)
plt.show()

# %%
ebola_sub = ebola[['Day', 'Cases_Guinea', 'Cases_Liberia']]
print(ebola_sub.tail(10))
# Out:
#             Day  Cases_Guinea  Cases_Liberia
# Date
# 2014-04-04   13         143.0           18.0
# 2014-04-01   10         127.0            8.0
# 2014-03-31    9         122.0            8.0
# 2014-03-29    7         112.0            7.0
# 2014-03-28    6         112.0            3.0
# 2014-03-27    5         103.0            8.0
# 2014-03-26    4          86.0            NaN
# 2014-03-25    3          86.0            NaN
# 2014-03-24    2          86.0            NaN
# 2014-03-22    0          49.0            NaN

# %%
ebola = pd.read_csv(
    '../data/country_timeseries.csv'
    , parse_dates = ['Date']
    , index_col = 'Date',
)
print(ebola.iloc[:, :4])
# Out:
#             Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# Date
# 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31  284        2730.0         8115.0             9633.0
# ...         ...           ...            ...                ...
# 2014-03-27    5         103.0            8.0                6.0
# 2014-03-26    4          86.0            NaN                NaN
# 2014-03-25    3          86.0            NaN                NaN
# 2014-03-24    2          86.0            NaN                NaN
# 2014-03-22    0          49.0            NaN                NaN
#
# [122 rows x 4 columns]

# %%
new_idx = pd.date_range(ebola.index.min(), ebola.index.max())
new_idx
# Out:
# DatetimeIndex(['2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25',
#                '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29',
#                '2014-03-30', '2014-03-31',
#                ...
#                '2014-12-27', '2014-12-28', '2014-12-29', '2014-12-30',
#                '2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', length=290, freq='D')

# %%
new_idx = reversed(new_idx)
new_idx

# %%
ebola = ebola.reindex(new_idx)
print(ebola.iloc[:, :4])
# Out:
#               Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# Date
# 2015-01-05  289.0        2776.0            NaN            10030.0
# 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-01    NaN           NaN            NaN                NaN
# ...           ...           ...            ...                ...
# 2014-03-26    4.0          86.0            NaN                NaN
# 2014-03-25    3.0          86.0            NaN                NaN
# 2014-03-24    2.0          86.0            NaN                NaN
# 2014-03-23    NaN           NaN            NaN                NaN
# 2014-03-22    0.0          49.0            NaN                NaN
#
# [290 rows x 4 columns]

# %%
last_valid = ebola.apply(pd.Series.last_valid_index)
last_valid
# Out:
# Day                   2014-03-22
# Cases_Guinea          2014-03-22
# Cases_Liberia         2014-03-27
# Cases_SierraLeone     2014-03-27
# Cases_Nigeria         2014-07-23
# Cases_Senegal         2014-08-31
# Cases_UnitedStates    2014-10-01
# Cases_Spain           2014-10-08
# Cases_Mali            2014-10-22
# Deaths_Guinea         2014-03-22
# Deaths_Liberia        2014-03-27
# Deaths_SierraLeone    2014-03-27
# Deaths_Nigeria        2014-07-23
# Deaths_Senegal        2014-09-07
# Deaths_UnitedStates   2014-10-01
# Deaths_Spain          2014-10-08
# Deaths_Mali           2014-10-22
# dtype: datetime64[ns]

# %%
earliest_date = ebola.index.min()
earliest_date
# Out:
# Timestamp('2014-03-22 00:00:00')

# %%
shift_values = last_valid - earliest_date
shift_values
# Out:
# Day                     0 days
# Cases_Guinea            0 days
# Cases_Liberia           5 days
# Cases_SierraLeone       5 days
# Cases_Nigeria         123 days
# Cases_Senegal         162 days
# Cases_UnitedStates    193 days
# Cases_Spain           200 days
# Cases_Mali            214 days
# Deaths_Guinea           0 days
# Deaths_Liberia          5 days
# Deaths_SierraLeone      5 days
# Deaths_Nigeria        123 days
# Deaths_Senegal        169 days
# Deaths_UnitedStates   193 days
# Deaths_Spain          200 days
# Deaths_Mali           214 days
# dtype: timedelta64[ns]

# %%
ebola_dict = {}

for idx, col in enumerate(ebola):
    d = shift_values.iloc[idx].days
    shifted = ebola[col].shift(d)
    ebola_dict[col] = shifted

# %%
ebola.head(10)
# Out:
#               Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2015-01-05  289.0        2776.0            NaN            10030.0
# 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-01    NaN           NaN            NaN                NaN
# 2014-12-31  284.0        2730.0         8115.0             9633.0
# 2014-12-30    NaN           NaN            NaN                NaN
# 2014-12-29    NaN           NaN            NaN                NaN
# 2014-12-28  281.0        2706.0         8018.0             9446.0
# 2014-12-27  280.0        2695.0            NaN             9409.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2015-01-05            NaN            NaN                 NaN          NaN
# 2015-01-04            NaN            NaN                 NaN          NaN
# 2015-01-03            NaN            NaN                 NaN          NaN
# 2015-01-02            NaN            NaN                 NaN          NaN
# 2015-01-01            NaN            NaN                 NaN          NaN
# 2014-12-31            NaN            NaN                 NaN          NaN
# 2014-12-30            NaN            NaN                 NaN          NaN
# 2014-12-29            NaN            NaN                 NaN          NaN
# 2014-12-28            NaN            NaN                 NaN          NaN
# 2014-12-27            NaN            NaN                 NaN          NaN
#
#             Cases_Mali  Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  \
# Date
# 2015-01-05         NaN         1786.0             NaN              2977.0
# 2015-01-04         NaN         1781.0             NaN              2943.0
# 2015-01-03         NaN         1767.0          3496.0              2915.0
# 2015-01-02         NaN            NaN          3496.0                 NaN
# 2015-01-01         NaN            NaN             NaN                 NaN
# 2014-12-31         NaN         1739.0          3471.0              2827.0
# 2014-12-30         NaN            NaN             NaN                 NaN
# 2014-12-29         NaN            NaN             NaN                 NaN
# 2014-12-28         NaN         1708.0          3423.0              2758.0
# 2014-12-27         NaN         1697.0             NaN              2732.0
#
#             Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# Date
# 2015-01-05             NaN             NaN                  NaN           NaN
# 2015-01-04             NaN             NaN                  NaN           NaN
# 2015-01-03             NaN             NaN                  NaN           NaN
# 2015-01-02             NaN             NaN                  NaN           NaN
# 2015-01-01             NaN             NaN                  NaN           NaN
# 2014-12-31             NaN             NaN                  NaN           NaN
# 2014-12-30             NaN             NaN                  NaN           NaN
# 2014-12-29             NaN             NaN                  NaN           NaN
# 2014-12-28             NaN             NaN                  NaN           NaN
# 2014-12-27             NaN             NaN                  NaN           NaN
#
#             Deaths_Mali
# Date
# 2015-01-05          NaN
# 2015-01-04          NaN
# 2015-01-03          NaN
# 2015-01-02          NaN
# 2015-01-01          NaN
# 2014-12-31          NaN
# 2014-12-30          NaN
# 2014-12-29          NaN
# 2014-12-28          NaN
# 2014-12-27          NaN

# %%
ebola_shift = pd.DataFrame(ebola_dict)

# %%
ebola_shift.head(10)
# Out:
#        Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Day
# 289.0        2776.0            NaN                NaN            NaN
# 288.0        2775.0            NaN                NaN            NaN
# 287.0        2769.0            NaN                NaN            NaN
# 286.0           NaN            NaN                NaN            NaN
# NaN             NaN            NaN                NaN            NaN
# 284.0        2730.0            NaN            10030.0            NaN
# NaN             NaN            NaN             9780.0            NaN
# NaN             NaN         8166.0             9722.0            NaN
# 281.0        2706.0         8157.0                NaN            NaN
# 280.0        2695.0            NaN                NaN            NaN
#
#        Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Day
# 289.0            NaN                 NaN          NaN         NaN
# 288.0            NaN                 NaN          NaN         NaN
# 287.0            NaN                 NaN          NaN         NaN
# 286.0            NaN                 NaN          NaN         NaN
# NaN              NaN                 NaN          NaN         NaN
# 284.0            NaN                 NaN          NaN         NaN
# NaN              NaN                 NaN          NaN         NaN
# NaN              NaN                 NaN          NaN         NaN
# 281.0            NaN                 NaN          NaN         NaN
# 280.0            NaN                 NaN          NaN         NaN
#
#        Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# Day
# 289.0         1786.0             NaN                 NaN             NaN
# 288.0         1781.0             NaN                 NaN             NaN
# 287.0         1767.0             NaN                 NaN             NaN
# 286.0            NaN             NaN                 NaN             NaN
# NaN              NaN             NaN                 NaN             NaN
# 284.0         1739.0             NaN              2977.0             NaN
# NaN              NaN             NaN              2943.0             NaN
# NaN              NaN          3496.0              2915.0             NaN
# 281.0         1708.0          3496.0                 NaN             NaN
# 280.0         1697.0             NaN                 NaN             NaN
#
#        Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# Day
# 289.0             NaN                  NaN           NaN          NaN
# 288.0             NaN                  NaN           NaN          NaN
# 287.0             NaN                  NaN           NaN          NaN
# 286.0             NaN                  NaN           NaN          NaN
# NaN               NaN                  NaN           NaN          NaN
# 284.0             NaN                  NaN           NaN          NaN
# NaN               NaN                  NaN           NaN          NaN
# NaN               NaN                  NaN           NaN          NaN
# 281.0             NaN                  NaN           NaN          NaN
# 280.0             NaN                  NaN           NaN          NaN

# %%
ebola_shift.index = ebola_shift['Day']
ebola_shift = ebola_shift.drop(['Day'], axis = 'columns')
ebola_shift.tail()
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Day
# 4.0          86.0            8.0                2.0            1.0
# 3.0          86.0            NaN                NaN            NaN
# 2.0          86.0            7.0                NaN            NaN
# NaN           NaN            3.0                2.0            NaN
# 0.0          49.0            8.0                6.0            0.0
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Day
# 4.0            NaN                 1.0          1.0         NaN
# 3.0            NaN                 NaN          NaN         NaN
# 2.0            NaN                 NaN          NaN         NaN
# NaN            NaN                 NaN          NaN         NaN
# 0.0            1.0                 1.0          1.0         1.0
#
#      Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# Day
# 4.0           62.0             4.0                 2.0             1.0
# 3.0           60.0             NaN                 NaN             NaN
# 2.0           59.0             2.0                 NaN             NaN
# NaN            NaN             3.0                 2.0             NaN
# 0.0           29.0             6.0                 5.0             0.0
#
#      Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# Day
# 4.0             NaN                  0.0           1.0          NaN
# 3.0             NaN                  NaN           NaN          NaN
# 2.0             NaN                  NaN           NaN          NaN
# NaN             NaN                  NaN           NaN          NaN
# 0.0             0.0                  0.0           1.0          1.0

# %%
down = ebola.resample('ME').mean()
down.iloc[:, :5]
# Out:
#                    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2014-03-31    4.500000     94.500000       6.500000           3.333333
# 2014-04-30   24.333333    177.818182      24.555556           2.200000
# 2014-05-31   51.888889    248.777778      12.555556           7.333333
# 2014-06-30   84.636364    373.428571      35.500000         125.571429
# 2014-07-31  115.700000    423.000000     212.300000         420.500000
# 2014-08-31  145.090909    559.818182     868.818182         844.000000
# 2014-09-30  177.500000    967.888889    2815.625000        1726.000000
# 2014-10-31  207.470588   1500.444444    4758.750000        3668.111111
# 2014-11-30  237.214286   1950.500000    7039.000000        5843.625000
# 2014-12-31  271.181818   2579.625000    7902.571429        8985.875000
# 2015-01-31  287.500000   2773.333333    8161.500000        9844.000000
#
#             Cases_Nigeria
# Date
# 2014-03-31            NaN
# 2014-04-30            NaN
# 2014-05-31            NaN
# 2014-06-30            NaN
# 2014-07-31       1.333333
# 2014-08-31      13.363636
# 2014-09-30      20.714286
# 2014-10-31      20.000000
# 2014-11-30      20.000000
# 2014-12-31      20.000000
# 2015-01-31            NaN

# %%
up = down.resample('D').mean()
up.iloc[:, :5]
# Out:
#               Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2014-03-31    4.5     94.500000            6.5           3.333333
# 2014-04-01    NaN           NaN            NaN                NaN
# 2014-04-02    NaN           NaN            NaN                NaN
# 2014-04-03    NaN           NaN            NaN                NaN
# 2014-04-04    NaN           NaN            NaN                NaN
# ...           ...           ...            ...                ...
# 2015-01-27    NaN           NaN            NaN                NaN
# 2015-01-28    NaN           NaN            NaN                NaN
# 2015-01-29    NaN           NaN            NaN                NaN
# 2015-01-30    NaN           NaN            NaN                NaN
# 2015-01-31  287.5   2773.333333         8161.5        9844.000000
#
#             Cases_Nigeria
# Date
# 2014-03-31            NaN
# 2014-04-01            NaN
# 2014-04-02            NaN
# 2014-04-03            NaN
# 2014-04-04            NaN
# ...                   ...
# 2015-01-27            NaN
# 2015-01-28            NaN
# 2015-01-29            NaN
# 2015-01-30            NaN
# 2015-01-31            NaN
#
# [307 rows x 5 columns]

# %%
import pytz

len(pytz.all_timezones)
# Out:
# 597

# %%
import re

regex = re.compile(r'^US')
selected_files = filter(regex.search, pytz.common_timezones)
print(list(selected_files))
# Out:
# ['US/Alaska', 'US/Arizona', 'US/Central', 'US/Eastern', 'US/Hawaii', 'US/Mountain', 'US/Pacific']

# %%
depart = pd.Timestamp('2017-08-29 07:00', tz = 'US/Eastern')
print(depart)
# Out:
# 2017-08-29 07:00:00-04:00

# %%
arrive = pd.Timestamp('2017-08-29 09:57')
print(arrive)
# Out:
# 2017-08-29 09:57:00

# %%
arrive = arrive.tz_localize('US/Pacific')
print(arrive)
# Out:
# 2017-08-29 09:57:00-07:00

# %%
print(arrive.tz_convert('US/Eastern'))
# Out:
# 2017-08-29 12:57:00-04:00

# %%
duration = arrive - depart
print(duration)
# Out:
# 0 days 05:57:00
