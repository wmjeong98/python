# %% [markdown]
# ## <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#필요한-모듈-import" data-toc-modified-id="필요한-모듈-import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>필요한 모듈 import</a></span></li><li><span><a href="#데이터-수집" data-toc-modified-id="데이터-수집-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>데이터 수집</a></span></li><li><span><a href="#데이터-탐색" data-toc-modified-id="데이터-탐색-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>데이터 탐색</a></span></li><li><span><a href="#데이터-준비---학습용-/-검증용-데이터-분리" data-toc-modified-id="데이터-준비---학습용-/-검증용-데이터-분리-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>데이터 준비 - 학습용 / 검증용 데이터 분리</a></span></li><li><span><a href="#모델-구축" data-toc-modified-id="모델-구축-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>모델 구축</a></span></li><li><span><a href="#모델-성능-평가" data-toc-modified-id="모델-성능-평가-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>모델 성능 평가</a></span></li><li><span><a href="#시각화" data-toc-modified-id="시각화-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>시각화</a></span><ul class="toc-item"><li><span><a href="#데이터-생성/수집" data-toc-modified-id="데이터-생성/수집-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>데이터 생성/수집</a></span></li><li><span><a href="#데이터-탐색" data-toc-modified-id="데이터-탐색-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>데이터 탐색</a></span></li><li><span><a href="#데이터-준비---학습용-/-검증용-데이터-분리" data-toc-modified-id="데이터-준비---학습용-/-검증용-데이터-분리-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>데이터 준비 - 학습용 / 검증용 데이터 분리</a></span></li></ul></li><li><span><a href="#데이터-수집" data-toc-modified-id="데이터-수집-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>데이터 수집</a></span></li><li><span><a href="#데이터-탐색" data-toc-modified-id="데이터-탐색-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>데이터 탐색</a></span></li><li><span><a href="#데이터-준비" data-toc-modified-id="데이터-준비-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>데이터 준비</a></span></li><li><span><a href="#학습용/-검증용-데이터-분리" data-toc-modified-id="학습용/-검증용-데이터-분리-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>학습용/ 검증용 데이터 분리</a></span></li><li><span><a href="#모델-구축" data-toc-modified-id="모델-구축-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>모델 구축</a></span></li><li><span><a href="#모델-평가" data-toc-modified-id="모델-평가-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>모델 평가</a></span></li><li><span><a href="#시각화" data-toc-modified-id="시각화-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>시각화</a></span></li></ul></div>

# %% [markdown]
# # 단순 선형 회귀

# %% [markdown]
# # < 사이킷런에서 최소제곱법으로 단순 선형회귀 수행 >

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 필요한 모듈 import

# %% [markdown]
# # 1. 맥주 데이터를 활용한 단순 선형 회귀 실습

# %% [markdown]
# ### 데이터 수집

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 데이터 탐색

# %%
beer = pd.read_csv('./data/beer.csv')
beer
# Out:
#     beer  temperature
# 0   45.3         20.5
# 1   59.3         25.0
# 2   40.4         10.0
# 3   38.0         26.9
# 4   37.0         15.8
# 5   40.9          4.2
# 6   60.2         13.5
# 7   63.3         26.0
# 8   51.1         23.3
# 9   44.9          8.5
# 10  47.0         26.2
# 11  53.2         19.1
# 12  43.5         24.3
# 13  53.2         23.3
# 14  37.4          8.4
# 15  59.9         23.5
# 16  41.5         13.9
# 17  75.1         35.5
# 18  55.6         27.2
# 19  57.2         20.5
# 20  46.5         10.2
# 21  35.8         20.5
# 22  51.9         21.6
# 23  38.2          7.9
# 24  66.0         42.2
# 25  55.3         23.9
# 26  55.3         36.9
# 27  43.3          8.9
# 28  70.5         36.4
# 29  38.8          6.4

# %%
# 데이터 탐색

plt.figure(figsize=(5, 5))
plt.scatter(beer['temperature'], beer['beer'])
plt.grid();

# %%
# 독립 변수, 종속 변수 확인

# %%
beer.temperature
# Out:
# 0     20.5
# 1     25.0
# 2     10.0
# 3     26.9
# 4     15.8
# 5      4.2
# 6     13.5
# 7     26.0
# 8     23.3
# 9      8.5
# 10    26.2
# 11    19.1
# 12    24.3
# 13    23.3
# 14     8.4
# 15    23.5
# 16    13.9
# 17    35.5
# 18    27.2
# 19    20.5
# 20    10.2
# 21    20.5
# 22    21.6
# 23     7.9
# 24    42.2
# 25    23.9
# 26    36.9
# 27     8.9
# 28    36.4
# 29     6.4
# Name: temperature, dtype: float64

# %%
# 종속 변수 확인, 레코드 수 확인
beer.beer
# Out:
# 0     45.3
# 1     59.3
# 2     40.4
# 3     38.0
# 4     37.0
# 5     40.9
# 6     60.2
# 7     63.3
# 8     51.1
# 9     44.9
# 10    47.0
# 11    53.2
# 12    43.5
# 13    53.2
# 14    37.4
# 15    59.9
# 16    41.5
# 17    75.1
# 18    55.6
# 19    57.2
# 20    46.5
# 21    35.8
# 22    51.9
# 23    38.2
# 24    66.0
# 25    55.3
# 26    55.3
# 27    43.3
# 28    70.5
# 29    38.8
# Name: beer, dtype: float64

# %%
len(beer.beer)
# Out:
# 30

# %% [markdown]
# ###  데이터 준비 - 학습용 / 검증용 데이터 분리

# %%
beer['temperature'].shape
# Out:
# (30,)

# %%
print(beer['temperature'])
# Out:
# 0     20.5
# 1     25.0
# 2     10.0
# 3     26.9
# 4     15.8
# 5      4.2
# 6     13.5
# 7     26.0
# 8     23.3
# 9      8.5
# 10    26.2
# 11    19.1
# 12    24.3
# 13    23.3
# 14     8.4
# 15    23.5
# 16    13.9
# 17    35.5
# 18    27.2
# 19    20.5
# 20    10.2
# 21    20.5
# 22    21.6
# 23     7.9
# 24    42.2
# 25    23.9
# 26    36.9
# 27     8.9
# 28    36.4
# 29     6.4
# Name: temperature, dtype: float64

# %%
beer_reshape = np.array(beer['temperature']).reshape(-1,1)
beer_reshape.shape
# Out:
# (30, 1)

# %%
print(beer_reshape)
# Out:
# [[20.5]
#  [25. ]
#  [10. ]
#  [26.9]
#  [15.8]
#  [ 4.2]
#  [13.5]
#  [26. ]
#  [23.3]
#  [ 8.5]
#  [26.2]
#  [19.1]
#  [24.3]
#  [23.3]
#  [ 8.4]
#  [23.5]
#  [13.9]
#  [35.5]
#  [27.2]
#  [20.5]
#  [10.2]
#  [20.5]
#  [21.6]
#  [ 7.9]
#  [42.2]
#  [23.9]
#  [36.9]
#  [ 8.9]
#  [36.4]
#  [ 6.4]]

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# 전체 데이터 중 80%는 학습용, 20%는 검증용으로 분리


#독립변수, 종속변수 데이터셋 준비
X = np.array(beer.temperature).reshape(-1, 1)
y = np.array(beer['beer'])

X_train, X_test, y_train, y_test = train_test_split(\
                            X, y, test_size=0.2,\
                            random_state=1)

# %% [markdown]
# ### 모델 구축

# %%
from sklearn.linear_model import LinearRegression
#모델 클래스 선택 후 인스턴스 객체 생성

lr = LinearRegression()

# %%
# 학습 수행
reg =lr.fit(X_train, y_train)

# %%
# 계수 및 절편 확인: _속성은 학습을 통해 결정되는 속성
reg.coef_, reg.intercept_
# Out:
# (array([0.69705648]), np.float64(36.06666541566105))

# %%
print(reg.coef_)  # 다항을 대비하기 위해 list 표현
# Out:
# [0.69705648]

# %%
print(reg.intercept_)
# Out:
# 36.06666541566105

# %%
a = 10
b = [10]

# %%
#회귀식
"y= {:.2f}X + {:.3f}".format(reg.coef_[0], reg.intercept_)
# Out:
# 'y= 0.70X + 36.067'

# %%
# 구축된 모델에서 예측 수행
X_test
# Out:
# array([[35.5],
#        [20.5],
#        [26.2],
#        [20.5],
#        [ 8.4],
#        [10.2]])

# %%
y_test
# Out:
# array([75.1, 35.8, 47. , 57.2, 37.4, 46.5])

# %%
y_pred = reg.predict(X_test)
print(np.round(y_pred, 2))
# Out:
# [60.81 50.36 54.33 50.36 41.92 43.18]

# %% [markdown]
# ### 모델 성능 평가

# %%
from sklearn.metrics import mean_squared_error, r2_score
#MSE
mse = mean_squared_error(y_test, y_pred)
#RMSE
rmse = np.sqrt(mse)

print('MSE: ', np.round(mse, 3))
print("RMSE: ", np.round(rmse, 3))
# Out:
# MSE:  91.347
# RMSE:  9.558

# %%
#결정계수 R2
r2 = r2_score(y_test, y_pred)
print("r2: ", np.round(r2, 3))
# Out:
# r2:  0.485

# %% [markdown]
# ### 시각화

# %%
beer.temperature.min() - 1
# Out:
# 3.2

# %%
beer.temperature.max() + 1
# Out:
# 43.2

# %%
xx = np.arange(3.2, 43.2)
xx
# Out:
# array([ 3.2,  4.2,  5.2,  6.2,  7.2,  8.2,  9.2, 10.2, 11.2, 12.2, 13.2,
#        14.2, 15.2, 16.2, 17.2, 18.2, 19.2, 20.2, 21.2, 22.2, 23.2, 24.2,
#        25.2, 26.2, 27.2, 28.2, 29.2, 30.2, 31.2, 32.2, 33.2, 34.2, 35.2,
#        36.2, 37.2, 38.2, 39.2, 40.2, 41.2, 42.2])

# %%
xx.shape
# Out:
# (40,)

# %%
yy = reg.predict(xx.reshape(-1, 1))

# %%
yy
# Out:
# array([38.29724615, 38.99430263, 39.69135911, 40.38841559, 41.08547207,
#        41.78252855, 42.47958503, 43.17664151, 43.87369799, 44.57075447,
#        45.26781095, 45.96486743, 46.66192391, 47.35898039, 48.05603687,
#        48.75309335, 49.45014983, 50.14720631, 50.84426279, 51.54131927,
#        52.23837575, 52.93543223, 53.63248871, 54.32954519, 55.02660167,
#        55.72365815, 56.42071463, 57.11777111, 57.81482759, 58.51188407,
#        59.20894055, 59.90599703, 60.60305351, 61.30010999, 61.99716647,
#        62.69422295, 63.39127943, 64.08833591, 64.78539239, 65.48244887])

# %%
#y = 0.697056X + 36.06 시각화
plt.figure(figsize=(5,5))
xx = np.arange(beer.temperature.min() - 1, \
              beer.temperature.max() + 1)

yy= reg.predict(xx.reshape(-1, 1))
plt.plot(xx, yy , linestyle='--', color='red')


# 수집한 데이터셋 시각화
plt.scatter(beer.temperature, beer.beer)
plt.grid()
plt.show()

# %% [markdown]
# # 응용1. 나이, 키의 관계를 회귀 분석

# %%
# 필요한 모듈 import 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 데이터 생성/수집

# %%
data_df = pd.read_csv('./data/age_height.csv')
data_df
# Out:
#           age      height
# 0   15.425550  170.910131
# 1   23.008112  160.675599
# 2    5.002859  129.002066
# 3   12.558314  159.701396
# 4    8.668897  155.460589
# 5    7.308465  140.561344
# 6    9.656505  153.654664
# 7   13.639018  159.429396
# 8   14.919187  164.704239
# 9   18.470418  169.645276
# 10  15.479863  160.712575
# 11  22.130488  173.287099
# 12  10.111306  159.311932
# 13  26.952936  171.517573
# 14   5.684690  138.957043
# 15  21.761688  165.874407

# %% [markdown]
# #### 데이터 탐색

# %%
# 데이터 분포 시각화

# %%
plt.figure(figsize=(5, 5))
plt.scatter(data_df['age'], data_df['height'])
plt.grid();

# %% [markdown]
# #### 데이터 준비 - 학습용 / 검증용 데이터 분리

# %%
# 전체 데이터 중 80%는 학습용, 20%는 검증용으로 분리
# random_state=1

X = np.array(data_df["age"]).reshape(-1,1)
y = data_df['height']

X_train, X_test, y_train, y_test = train_test_split(X, y, \
                        test_size=0.2, random_state=1)

# %%
X_test
# Out:
# array([[12.558314],
#        [26.952936],
#        [13.639018],
#        [ 5.002859]])

# %%
y_test
# Out:
# 3     159.701396
# 13    171.517573
# 7     159.429396
# 2     129.002066
# Name: height, dtype: float64

# %%
#####모델 구축 및 예측

# %%
#모델 객체 생성  및 학습
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

reg = lr.fit(X_train, y_train)

# 예측 수행
y_pred = reg.predict(X_test)

# %%
#####모델 성능 평가
from sklearn.metrics import mean_squared_error, r2_score
#MSE : metrcics 모듈의 mean_squared_error() 함수 사용
#RMSE : numpy의 sqrt() 함수 사용

# MSE
mse = mean_squared_error(y_test, y_pred)
# RMSE
rmse = np.sqrt(mse)

#R2
#결정계수 R2
r2 = r2_score(y_test, y_pred)

print(mse)
print(rmse)
print(r2)

#회귀식

print("y = {:.3f}X + {:.3f}".format(reg.coef_[0], reg.intercept_))
# Out:
# 83.49484708025096
# 9.137551481674452
# 0.6627884094930383
# y = 1.439X + 138.784

# %%
data_df["age"].min() - 1
# Out:
# np.float64(4.002859)

# %%
data_df["age"].max() + 1
# Out:
# np.float64(27.952936)

# %%
#나이, 키 데이터 실제 데이터 및 회귀식 시각화

xx =  np.arange(data_df['age'].min() -1, data_df['age'].max() + 1)
yy = reg.predict(xx.reshape(-1, 1))

plt.plot(xx, yy, linestyle="--", color='red')

plt.scatter(data_df['age'], data_df['height']);

# %% [markdown]
# # < 스탯츠모델에서 단순선형회귀 수행>

# %%
#스탯츠모델 import
import statsmodels.api as sm

# 맥주 데이터 
beer = pd.read_csv('./data/beer.csv')

X = np.array(beer.temperature).reshape(-1,1)
y = beer.beer

from sklearn.model_selection import train_test_split
import numpy as np

# 전체 데이터 중 80%는 학습용, 20%는 검증용으로 분리


X_train, X_test, y_train, y_test = train_test_split(\
                            X, y, test_size=0.2,\
                            random_state=1)


#독립변수, 종속변수 데이터셋 준비
X_train = sm.add_constant(X_train)
X_train
# Out:
# array([[ 1. , 36.9],
#        [ 1. , 26.9],
#        [ 1. , 42.2],
#        [ 1. , 21.6],
#        [ 1. ,  7.9],
#        [ 1. , 15.8],
#        [ 1. , 10. ],
#        [ 1. , 23.9],
#        [ 1. , 13.5],
#        [ 1. , 27.2],
#        [ 1. , 23.3],
#        [ 1. , 26. ],
#        [ 1. ,  8.9],
#        [ 1. , 25. ],
#        [ 1. , 13.9],
#        [ 1. , 20.5],
#        [ 1. , 23.5],
#        [ 1. ,  6.4],
#        [ 1. , 36.4],
#        [ 1. ,  8.5],
#        [ 1. , 23.3],
#        [ 1. , 24.3],
#        [ 1. , 19.1],
#        [ 1. ,  4.2]])

# %%
# 스탯츠모델 객체 생성

lr = sm.OLS(y_train, X_train)

# 학습
reg = lr.fit()

# %%
# 성능 평가
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   beer   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     22.63
# Date:                Thu, 05 Jun 2025   Prob (F-statistic):           9.50e-05
# Time:                        15:20:51   Log-Likelihood:                -79.854
# No. Observations:                  24   AIC:                             163.7
# Df Residuals:                      22   BIC:                             166.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.0667      3.315     10.881      0.000      29.193      42.941
# ...

# %% [markdown]
# # 응용: 농어 길이에서 농어의 무게 예측

# %%
perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 21.0,
       21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 22.5, 22.7,
       23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 27.3, 27.5, 27.5,
       27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 36.5, 36.0, 37.0, 37.0,
       39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 40.0, 42.0, 43.0, 43.0, 43.5,
       44.0])
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

# %%
perch_length.shape
# Out:
# (56,)

# %%
X = np.array(perch_length).reshape(-1, 1)  # 행열로 데이터 재구성
y = perch_weight

# %%
X.shape
# Out:
# (56, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, \
                                    test_size=0.2, random_state=1)

# %%
X_test, y_test
# Out:
# (array([[39. ],
#         [15. ],
#         [39. ],
#         [22.5],
#         [27.5],
#         [27.5],
#         [30. ],
#         [35. ],
#         [40. ],
#         [37. ],
#         [40. ],
#         [22.7]]),
#  array([ 900.,   40.,  820.,  130.,  265.,  250.,  320.,  840., 1015.,
#          700.,  900.,  145.]))

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

reg = lr.fit(X_train, y_train)

reg.coef_, reg.intercept_
# Out:
# (array([35.63110638]), np.float64(-618.3317511711566))

# %%
y_pred = reg.predict(X_test)

# %%
def print_score(y_test, y_pred):
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    
    print("MSE: {:.3f}".format(mse))
    print("RMSE: {:.3f}".format(rmse))
    print("R2 Score: {:.3f}".format(r2))
    return

# %%
# 모델 성능 평가
# mse, rmse, r2

from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MSE: {:.3f}".format(mse))
print("RMSE: {:.3f}".format(rmse))
print("R2 Score: {:.3f}".format(r2))
# Out:
# MSE: 14550.237
# RMSE: 120.624
# R2 Score: 0.880

# %%
plt.scatter(perch_length, perch_weight)

# 예측값
xx = np.arange(X.min() - 1, X.max() + 1)
yy = reg.predict(xx.reshape(-1, 1))

plt.plot(xx, yy, linestyle=":", color="magenta")

# %% [markdown]
# # 응용: 보스턴 집값 단순선형 회귀(방의 갯수 VS 주택가격)

# %% [markdown]
# ### 데이터 수집

# %%
from sklearn.datasets import load_boston

# %%
# boston = load_boston()

# %%
# boston.keys()

# %% [raw]
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
# print(boston.DESCR)

# %%
boston = pd.read_csv('./data/BostonHousingData.csv')

# %%
boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
import pandas as pd

pd.options.display.float_format = '{:.5f}'.format

# %%
# boston.data[:5]

# %%
boston['MEDV']   # target (Price)
# Out:
# 0     24.00000
# 1     21.60000
# 2     34.70000
# 3     33.40000
# 4     36.20000
#         ...
# 501   22.40000
# 502   20.60000
# 503   23.90000
# 504   22.00000
# 505   11.90000
# Name: MEDV, Length: 506, dtype: float64

# %%
df = boston
df
# Out:
#        CRIM       ZN    INDUS    CHAS     NOX      RM      AGE     DIS  RAD  \
# 0   0.00632 18.00000  2.31000 0.00000 0.53800 6.57500 65.20000 4.09000    1
# 1   0.02731  0.00000  7.07000 0.00000 0.46900 6.42100 78.90000 4.96710    2
# 2   0.02729  0.00000  7.07000 0.00000 0.46900 7.18500 61.10000 4.96710    2
# 3   0.03237  0.00000  2.18000 0.00000 0.45800 6.99800 45.80000 6.06220    3
# 4   0.06905  0.00000  2.18000 0.00000 0.45800 7.14700 54.20000 6.06220    3
# ..      ...      ...      ...     ...     ...     ...      ...     ...  ...
# 501 0.06263  0.00000 11.93000 0.00000 0.57300 6.59300 69.10000 2.47860    1
# 502 0.04527  0.00000 11.93000 0.00000 0.57300 6.12000 76.70000 2.28750    1
# 503 0.06076  0.00000 11.93000 0.00000 0.57300 6.97600 91.00000 2.16750    1
# 504 0.10959  0.00000 11.93000 0.00000 0.57300 6.79400 89.30000 2.38890    1
# 505 0.04741  0.00000 11.93000 0.00000 0.57300 6.03000      NaN 2.50500    1
#
#      TAX  PTRATIO         B   LSTAT     MEDV
# ...

# %%
X = df["RM"]
X
# Out:
# 0     6.57500
# 1     6.42100
# 2     7.18500
# 3     6.99800
# 4     7.14700
#         ...
# 501   6.59300
# 502   6.12000
# 503   6.97600
# 504   6.79400
# 505   6.03000
# Name: RM, Length: 506, dtype: float64

# %%
y = df['MEDV']
y
# Out:
# 0     24.00000
# 1     21.60000
# 2     34.70000
# 3     33.40000
# 4     36.20000
#         ...
# 501   22.40000
# 502   20.60000
# 503   23.90000
# 504   22.00000
# 505   11.90000
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# ### 데이터 탐색

# %% [raw]
# 14개의 변수(피처)의 의미
# CRIM: 지역별 범죄 발생률
#  ZN: 25,000평방피트를 초과하는 거주 지역 비율
#  INDUS: 비상업 지역의 넓이 비율
#  CHAS: 찰스강의 더미변수(1은 강의 경계, 0은 경계 아님)
#  NOX: 일산화질소 농도
#  RM: 거주할 수 있는 방 개수
#  AGE: 1940년 이전에 건축된 주택 비율
#  DIS: 5개 주요 고용센터까지 가중 거리
#  RAD: 고속도로 접근 용이도
# TAX: 10,000달러당 재산세 비율
# PTRATIO: 지역의 교사와 학생 수 비율
# B: 지역의 흑인 거주 비율
# LSTAT: 하위 계층의 비율
# PRICE(MEDV): 본인 소유 주택 가격의 중앙값
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 데이터 준비

# %%
# boston 데이터에서 독립변수(RM), 종속 변수를 각각 골라내고 데이터프레임으로 변환

# %%
X = df['RM']
y = df['MEDV']   # price

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X, y, s=3, c='red')
plt.grid();

# %% [markdown]
# ### 학습용/ 검증용 데이터 분리

# %%
# 조건 : 학습 7, 검증 3
# seed  = 1로 고정

from sklearn.model_selection import train_test_split

X = np.array(X).reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
len(X_test)
# Out:
# 152

# %%
X_train[:5]
# Out:
# array([[5.949],
#        [5.966],
#        [6.794],
#        [6.595],
#        [3.561]])

# %% [markdown]
# ### 모델 구축

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
reg = lr.fit(X_train, y_train)

# %% [markdown]
# ### 모델 평가

# %%
# mse, rmse, r2

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = reg.predict(X_test)
# MSE
mse = mean_squared_error(y_test, y_pred)

# RMSE
rmse = np.sqrt(mse)

#r2_score

r2 = r2_score(y_test, y_pred)

print(mse, rmse, r2)

## print(score(y_test, y_pred))
# Out:
# 36.51721473083863 6.042947520112898 0.6015774471545621

# %% [markdown]
# ### 시각화

# %%
# 방의 갯수와 주택 중간 가격 관계 시긱화

plt.figure(figsize=(5, 5))
xx = np.arange(X.min() -1, X.max()+1)
yy = reg.predict(xx.reshape(-1, 1))

plt.plot(xx, yy, linestyle='--', c='b')

plt.scatter(df['RM'], df['MEDV'], s=3, c='r')
plt.grid()

# %%
xx = np.arange(X.min() -1, X.max()+1)
yy = reg.predict(xx.reshape(-1, 1))

# %%
xx
# Out:
# array([2.561, 3.561, 4.561, 5.561, 6.561, 7.561, 8.561, 9.561])

# %%
yy
# Out:
# array([-8.90217673, -0.44108509,  8.02000655, 16.48109818, 24.94218982,
#        33.40328146, 41.86437309, 50.32546473])
